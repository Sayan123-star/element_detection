# %%
# Importing the drive to get  access to Google Drive
from google.colab import drive

# %%
# Getting access to the file for yolo v8 traing, valid and test datasets that Are annotated with data.yaml contains  bounding boxes in form of x,y,w,h
drive.mount('\content\drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-b045c5882468> in <cell line: 1>()
# ----> 1 drive.mount('\content\drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     254
#     255   while True:
# --> 256     case = d.expect([
#     257         success,
#     258         prompt,
#
# ...

# %%
# ultralytics is a library for detecting objects
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.0/715.0 kB 7.1 MB/s eta 0:00:00
# ...

# %%
# Initially detecting objects without custom labeled dataset
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/webpage1.PNG'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 83.0MB/s]
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/webpage1.PNG: 640x320 1 kite, 2 sandwichs, 305.6ms
# Speed: 17.1ms preprocess, 305.6ms inference, 38.0ms postprocess per image at shape (1, 3, 640, 320)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Visualising the image after initial detection
from IPython.display import Image
Image('/content/runs/detect/predict/webpage1.PNG', width=500, height=500)

# %%
# Training the model accocding to the dataset with annotated  data
# !yolo task=detect mode=train model=yolov8s.pt data='/content/Web elemet.v3i.yolov8/data.yaml' epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# Predicting the model of the image after applying the annoted dataset with the yolov8
# !yolo task=detect mode=predict model=/content/runs/detect/train2/weights/best.pt conf=0.25 source=/content/webpage1.PNG
# Out:
# Ultralytics YOLOv8.1.14 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11129067 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/1 /content/webpage1.PNG: 640x320 5 buttonss, 1 icon, 2 imagess, 1 input fields, 1 text, 379.6ms
# Speed: 15.4ms preprocess, 379.6ms inference, 6.6ms postprocess per image at shape (1, 3, 640, 320)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# Visualising the predicted image
Image('/content/runs/detect/predict2/webpage1.PNG', width=600, height=1000)
